# %% [markdown]
# # Data Scientist Course!

# %% [markdown]
# Benvenuti al nostro corso per scienziati dei dati
#
# Questo è il corso introduttivo di base, orinario tenuto da: Andrea Guzzo e Salvatore Albore.
#
# L'obiettivo del corso è quello di insegnarvi le basi e tutto ciò di cui avete bisogno per iniziare a lavorare nel meraviglioso mondo della scienza dei dati.

# %% [markdown]
# ## What is Data Science?

# %% [markdown]
# Data Science, nota anche come: scienza basata sui dati, è un campo interdisciplinare che riguarda metodi, processi e sistemi scientifici per estrarre conoscenze o intuizioni dai dati in varie forme, sia strutturate che non strutturate.
#
# Ci sono molte definizioni sulla scienza dei dati, per esempio:
# - La scienza dei dati è un "concetto per unificare la statistica, l'analisi dei dati e i loro metodi correlati" al fine di "comprendere e analizzare i fenomeni reali" con i dati. - Chikio Hayashi
#
# Ed è impossibile non menzionare anche il: Machine Learning
# - L'apprendimento automatico è un "campo di studio che dà ai computer la possibilità di imparare senza essere esplicitamente programmati" - Arthur Samuel
#
# Quindi l'obiettivo dell'apprendimento automatico (Machine Learning) è:
# - programmare i computer per usare dati di esempio o esperienze passate per risolvere un dato problema
#
# Quindi usiamo Data Science e Machine Learning per consentire ai computer di aiutarci a capire o a fare previsioni sul mondo.
#
# Quando parliamo di scienza dei dati, parliamo anche di **Analisi dei dati**
# **L'analisi dei dati** --> è un processo attraverso il quale si indaga su grandi quantità di dati per determinare le conlusioni e per supportare il processo decisionale, quindi dobbiamo guardare a ciò che i dati stanno cercando di dirci.
#
# <img src="risorse/analisi dei dati.png">
#
# Ma in pratica? What do you do in a Data Science project or work?
#
# - Capire come lavorare con i dati (estrazione, pulizia e organizzazione) da molte fonti diverse con diversi tipi di dati (dati strutturati, non strutturati)
# - Saper identificare le qualità, il valore all'interno dei set di dati
# - Saper costruire esperimenti predittivi o modelli di calcolo
# - Saper visualizzare e contestualizzare i risultati prodotti al fine di produrre report o servizi per il consumo dei modelli
#
# Questo processo è anche chiamato: **Data Driven Approach**
#
# <img src="resources/data-driven.png">
#
# <img src="resources/data-driven-explained.png">

# %% [markdown]
# ## Che cos'è l'Intelligenza Artificiale?

# %% [markdown]
# Non esiste una definizione giusta, corretta o completa, spesso si evolvono e cambiano nel tempo...
# È molto difficile definire cosa sia Intelligenza Artificiale perchè allo stesso tempo è difficile definire cosa sia Intelligenza.
#
# Ci sono inoltre tanti retaggi della fantascienza, che però faticano ad avere un riscontro con il mondo reale.
#
# Proviamo comunque a trovare delle definizioni per definire meglio il contesto, utilizzando alcune definizioni autorevoli che si possono trovare nel web:
#
# Merriam-Webster definisce l'intelligenza artificiale in questo modo:
#
#     Un ramo dell'informatica che si occupa della simulazione del comportamento intelligente nei computer.
#     La capacità di una macchina di imitare il comportamento umano intelligente.
#
# L'Enciclopedia Britannica afferma,
#
#     "Intelligenza artificiale (AI), la capacità di un computer digitale o di un robot controllato da un computer di svolgere compiti comunemente associati agli esseri intelligenti".
#     Gli esseri intelligenti sono quelli in grado di adattarsi al cambiamento delle circostanze.
#
#
# L'Unione europea, con una commissione specifica, ha creato le linee guida etiche europee per un'IA affidabile.
# https://ec.europa.eu/digital-single-market/en/news/ethics-guidelines-trustworthy-ai
# https://ec.europa.eu/futurium/en/ai-alliance-consultation
#
# la definizione che hanno dato è la seguente:
#
#     "Intelligenza artificiale (IA) si riferisce a sistemi che mostrano un comportamento intelligente analizzando il loro ambiente e intraprendendo azioni - con un certo grado di autonomia - per raggiungere obiettivi specifici.
#     I sistemi basati sull'intelligenza artificiale possono essere puramente software, agendo nel mondo virtuale (ad esempio assistenti vocali, software di analisi delle immagini, motori di ricerca, sistemi di riconoscimento vocale e facciale) o l'intelligenza artificiale può essere incorporata in dispositivi hardware (ad esempio robot avanzati, auto autonome, droni o applicazioni Internet of Things)".
#
#
# Il mantra dell'IA è: Ciò che sembra facile è in realtà difficile... e ciò che sembra difficile è in realtà facile
#
# Per dare una definizione corretta, è forse più utile ragionare per applicazioni concrete e per modi di risolvere determinati problemi.
# Alcuni esempi di applicazione di algoritmi di apprendimento automatico sono:
# - Sistemi di macchine a guida autonoma
# - Sistemi di analisi di anomalie in tempo reale (es: frodi bancarie, sensori, ...)
# - Agenti intelligenti e simulazione
# - Algoritmi in grado di giocare a giochi da tavolo o elettronici meglio degli umani
# - Sistemi di diagnosi medica avanzati e automatici
# - Analisi del testo automatizzata, sentiment analysis o traduttori automatici
# - Chatbot testuali e vocali
# - ...
#
# Ci sono però due argomenti principali, due termini che sono estremamente importanti quando si parla di IA:
#
# **Autonomia**
# - Si tratta della capacità di eseguire compiti in ambienti complessi senza una guida costante da parte dell'utente.
#
# **Attività**
# - Questa è la capacità di migliorare le prestazioni imparando dall'esperienza.
#
# C'è un ciclo di vita per realizzare un progetto, un'applicazione nel campo dell'Intelligenza Artificiale
#
# <img src="resources/ai-lifecycle.png">
#
# Quando si parla di Intelligenza Artificiale, Machine Learning, Deep Learning, ecc... è opportuno inoltre fare le dovute distinzioni e raggruppamenti per evitare fraintendimenti.
#
#
# <img src="resources/ai.png">

# %% [markdown]
# ## Kaggle!

# %% [markdown]
# Kaggle è un AirBnB for Data Scientists - è qui che trascorrono principalmente le loro notti e i loro fine settimana.
# Si tratta di una piattaforma di crowdsourcing per attrarre, nutrire, formare e sfidare gli scienziati dei dati di tutto il mondo per risolvere i problemi di data science, machine learning e analisi predittiva.
# Ha oltre 536.000 membri attivi provenienti da 194 paesi e riceve quasi 150.000 contributi al mese.
# https://www.kaggle.com/getting-started/44916

# %% [markdown]
# Potete usare Kaggle per cercare set di dati disponibili gratuitamente, vedere altre applicazioni, competere in sfide con altri Data Scientist, guardare e imparare dal codice di altre persone e iniziare a creare un curriculum in quest'ambito.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('TNzDMOg_zsw')

# %% [markdown]
# In questo corso useremo kaggle per alcuni set di dati ed esempio che potrete utilizzare per realizzare il progetto finale del corso

# %% [markdown]
# # Data Science: Percorso di Apprendimento

# %% [markdown]
# Il mondo della scienza dei dati è vasto e infinito, un oceano!
# È molto utile avere dei riferimenti, una guida per cercare di fare ordine e non perdersi in questo mare infinito di articoli, lezioni, corsi, libri...
# Questo è solo un primo corso introduttivo, poi ci sarà anche un corso avanzato, ma online si possono trovare molte risorse valide (a pagamento e/o gratuite) da cui imparare molto e costruire il proprio curriculum e il proprio percorso!
# Quindi qui entriamo nel nostro percorso di apprendimento. Ogni variazione, modifica e discussione è benvenuta! Possiamo costruire un percorso di apprendimento insieme e anche sulla base del vostro feedback possiamo modellarne uno che sia il più funzionale e migliore possibile.

# %% [markdown]
# Repository con tutti i migliori corsi disponibili online, con la loro descrizione e informazioni
# https://www.notion.so/The-Best-Artificial-Intelligence-Machine-Learning-and-Data-Science-Resources-b3b97fa097b747698e87fd3badc657cf

# %% [markdown]
# <img src="resources/roadmap.png" style="background-color:white;">

# %% [markdown]
# <br> <br>
# Non abbiate paura! La strada è lunga e ci sono tante cose da imparare... il segreto è tenere a mente l'obiettivo e fare un passo alla volta, lentamente.
# <br>
# <br> <br>

# %% [markdown]
# <img src="resources/roadmap_2.png">

# %% [markdown]
# <img src="resources/path.png">

# %% [markdown]
# ## Pietre Miliari

# %% [markdown]
# Attenzione: Molti corsi sono in lingua Inglese, ci rendiamo conto che non tutti conosono l'inglese, ma è un requisito fondamentale per lavorare nel mondo dell'informatica.
# Tutto il miglior materiale disponibile è solitamente in lingua anglofona

# %% [markdown]
# Standard python
# - [ ] Array, Types, Variables, Strings: Basics
# - [ ] Functions
# - [ ] Working with files (csv, json, ...)
# - [ ] Dates and Times
# - [ ] Data Structures: list, dictionaries, ...
# - [ ] Lamba and List Comprehensions
# - [ ] Objects and OOP
# - Software developing
# - Web developing
# - Web scraping and crawling
# - ORM (Object Relational Models)
#
# Linear Algebra and Mathematics
#
# https://github.com/mjbahmani/10-steps-to-become-a-data-scientist/blob/master/3-%20Mathematics%20and%20Linear%20Algebra/Linear%20Algebra%20for%20Data%20Scientists.ipynb
#
# - Linear Algebra
# https://www.khanacademy.org/math/linear-algebra
#
# - Calculus
# https://www.khanacademy.org/math/multivariable-calculus
#
# - Matrices
# https://www.khanacademy.org/math/precalculus-2018/precalc-matrices
#
# - Statistics and Probabilities
# https://www.khanacademy.org/math/statistics-probability
#
# - Coursera math for data science complete course (payment)
# https://www.coursera.org/specializations/mathematics-machine-learning?ranMID=40328&ranEAID=EBOQAYvGY4A&ranSiteID=EBOQAYvGY4A-A2ykkSIPhw_lMkynNexgjQ&siteID=EBOQAYvGY4A-A2ykkSIPhw_lMkynNexgjQ&utm_content=2&utm_medium=partners&utm_source=linkshare&utm_campaign=EBOQAYvGY4A
#
# Python libraries and tools
# <img src="resources/python_libraries.png" style="background-color:white;">
# - [ ] Numpy
#     - Creating, combining and iterating over arrays
#     - Operations
#     - Math Functions
#     - Indexing / Slicing
#     - Copying data
#     - Series data structure (querying)
# - [ ] Pandas
#     - Data frame (creating, indexing, structure, loading, merging)
#     - Missing values
#     - Pandorable Code
#     - Group by
#     - Pivot
#     - Date functionalities
#     - Distributions in pandas
#     - Hypothesis testing
#     - Plot (Matplotlib)
#         - Scatterpolots
#         - Lineplots
#         - Bar charts
#         - Histograms
#         - Box plots
#         - Heatmaps
#         - Animations
#         - Intactivity
#  - [ ] Seaborn
#      - Seaborn vs Matplotlib
#      - Useful Python data visualization libraries
#  - [ ] Sklearn
#      - Introduction
#      - Algorithms
#      - Framework
#      - Applications
#      - Data (cross val, split, ..)
#      - Supervised Learning
#          - Classification
#          - Regression
#          - linear, binary classification
#          - prediction
#          - three-class problems
#          - evaluation
#          - ....
#     - Unsupervised Learning
#         - Clustering
#         - Evaluations
#
# - [ ] Data Science workflow and questions (Introduction)
# https://www.kaggle.com/mjbahmani/a-data-science-framework-for-quora
# https://docs.microsoft.com/en-us/azure/machine-learning/team-data-science-process/overview

# %% [markdown]
# Usefull tips - technical notes

# %% [markdown]
# https://chrisalbon.com/

# %% [markdown]
# Data Scientist's Toolbox

# %% [markdown]
# https://www.kaggle.com/mjbahmani/the-data-scientist-s-toolbox-tutorial-1

# %% [markdown]
# #### Project Ideas

# %% [markdown]
# https://github.com/NirantK/awesome-project-ideas

# %% [markdown]
# #### Fastai Free Machine Learning and Deep Learning Course

# %% [markdown]
# https://www.fast.ai/

# %% [markdown]
# <br>
# <br>
# Ma soprattutto: prova, prova e prova...
# Trovate i casi d'uso, fate progetti, chiedete e trovate casi d'uso da risolvere e su cui lavorare... e mentre cercate le risposte alle vostre domande!
# <br>
# <br>

# %% [markdown]
# #### Free AI Beginner Course

# %% [markdown]
# https://course.elementsofai.com/

# %% [markdown]
# #### Useful Books

# %% [markdown]
# Python Data Science Handbook (livebook free) to understand and practise python libraries for Data Science (pandas, numpy, sklearn, ...)
# https://jakevdp.github.io/PythonDataScienceHandbook/
# <br>
# Machine Learning pratical book (To read and follow before the previous one)
# https://icenamor.github.io/files/books/Hands-on-Machine-Learning-with-Scikit-2E.pdf

# %% [markdown]
# #### Best Courses for us

# %% [markdown]
# - Introduction Courses
# https://www.edx.org/course/introduction-to-data-science-5
# https://www.edx.org/course/introduction-to-artificial-intelligence-ai-3
#
# - Machine Learning Theory Course
# https://www.coursera.org/learn/machine-learning
#
# - Deep Learning courses
# https://www.deeplearning.ai/

# %% [markdown]
# ### BONUS: Tecniche di apprendimento quotidiano
# Sicuramente sono cose comuni... ma è bene rinfrescarle :-)

# %% [markdown]
# 1. Dormi bene.
# 2. Esercizio 3-5x a settimana
# 3. Docce fredde per aumentare la vigilanza
# 4. Meditare 30 minuti al giorno
# 5. Nessun alimento trattato o farmaco.
# 6. Niente social media al mattino.
# 7. Pianificazione degli obiettivi di apprendimento
# 8. Liste sociali curate
# 9. Insegnate costantemente ciò che avete imparato. Stile ELI5.
# 10. Fare pause frequenti.
#
# - 11. Imparare ad imparare il corso (passiamo tutta la vita ad imparare, ma nessuno ci insegna ad imparare :-) )
# https://www.coursera.org/learn/learning-how-to-learn?utm_term=danielbourke_learning-how-to-learn_jan2019&ranMID=40328&ranEAID=EBOQAYvGY4A&ranSiteID=EBOQAYvGY4A-7uOXiO4VCvcZd1kuDd6x4A&siteID=EBOQAYvGY4A-7uOXiO4VCvcZd1kuDd6x4A&utm_content=10&utm_medium=partners&utm_source=linkshare&utm_campaign=EBOQAYvGY4A

# %% [markdown]
# #### Compendium about AI
#
# Community complete guide about: Courses, Researchers, Papers, Datasets, Tutorials, Conferences and a lot more
#
# https://hackmd.io/@chanderA/aiguide

# %% [markdown]
# #### Deep Learning Theory (Stanford)
# http://ufldl.stanford.edu/tutorial/

# %% [markdown]
# #### Reinforcement Learning (OpenAI)
# https://spinningup.openai.com/en/latest/

# %% [markdown]
# # Cheatsheet

# %% [markdown]
# Un cheat sheet o un crib sheet è un insieme conciso di note usate per rapida consultazione.
# Sono anche chiamati bigini o bigliettini perché possono essere usati dagli studenti a insaputa dell'istruttore per imbrogliare su un test.
# In Programmazione e Data Science sono utili perchè permettono di ricordare aspetti chiave e importanti senza perdere molto tempo alla ricerca delle stesse informazioni.

# %% [markdown]
# Pandas Cheatsheet
# https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf

# %% [markdown]
# Numpy Cheatsheet
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf

# %% [markdown]
# Python Cheatsheet
# https://perso.limsi.fr/pointal/_media/python:cours:mementopython3-english.pdf
# https://www.pythonsheets.com
# https://www.pythoncheatsheet.org/

# %% [markdown]
# Matplotlib Cheatsheet
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf

# %% [markdown]
# Seaborn Cheatsheet
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf

# %% [markdown]
# Complete Machine Learning and Deep Learning Theory Cheatsheet
# https://stanford.edu/~shervine/teaching/cs-229/cheatsheet-supervised-learning

# %% [markdown]
# Sklearn Cheatsheet
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Scikit_Learn_Cheat_Sheet_Python.pdf

# %% [markdown]
# # Storia

# %% [markdown]
# Se siete curiosi e volete approfondire un po' di storia dell'intelligenza artificiale, qui trovate alcune informazioni a riguardo

# %% [markdown]
# - Artificial Intelligence History
# https://towardsdatascience.com/history-of-ai-484a86fc16ef
# http://sitn.hms.harvard.edu/flash/2017/history-artificial-intelligence/
# https://learn.g2.com/history-of-artificial-intelligence
# https://www.javatpoint.com/history-of-artificial-intelligence
#
# - Machine Learning History
# https://www.doc.ic.ac.uk/~jce317/history-machine-learning.html
# https://www.bbc.com/timelines/zypd97h
# https://cloud.withgoogle.com/build/data-analytics/explore-history-machine-learning/
